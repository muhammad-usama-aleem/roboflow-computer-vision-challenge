# %% [markdown]
# <a href="https://colab.research.google.com/github/muhammad-usama-aleem/roboflow-computer-vision-challenge/blob/main/Validate%20Detections%20in%20Rows%20and%20Columns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
data = [{"x0": 304.0, "y0": 886.0, "x1": 758.0, "y1": 1256.0, "class_name": "Crunchy Toffee"},
        {"x0": 918.0, "y0": 881.0, "x1": 1267.0, "y1": 1251.0, "class_name": "Signature Caramel"},
        {"x0": 1425.0, "y0": 878.0, "x1": 1766.0, "y1": 1248.0, "class_name": "Signature Caramel"},
        {"x0": 1895.0, "y0": 887.0, "x1": 2222.0, "y1": 1206.0, "class_name": "Chocolate Orange Creme Crunch"},
        {"x0": 2346.0, "y0": 887.0, "x1": 2662.0, "y1": 1184.0, "class_name": "Chocolate Orange Creme Crunch"},
        {"x0": 321.0, "y0": 1420.0, "x1": 771.0, "y1": 1784.0, "class_name": "Crunchy Toffee"},
        {"x0": 938.0, "y0": 1412.0, "x1": 1301.0, "y1": 1784.0, "class_name": "Signature Caramel"},
        {"x0": 1454.0, "y0": 1422.0, "x1": 1797.0, "y1": 1785.0, "class_name": "Signature Caramel"},
        {"x0": 1924.0, "y0": 1384.0, "x1": 2203.0, "y1": 1836.0, "class_name": "Turkish Delight"},
        {"x0": 2369.0, "y0": 1331.0, "x1": 2660.0, "y1": 1768.0, "class_name": "Turkish Delight"},
        {"x0": 397.0, "y0": 1963.0, "x1": 832.0, "y1": 2361.0, "class_name": "Vanilla Frappe"},
        {"x0": 1063.0, "y0": 1941.0, "x1": 1466.0, "y1": 2335.0, "class_name": "Golden Fudge"},
        {"x0": 1666.0, "y0": 1933.0, "x1": 2051.0, "y1": 2298.0, "class_name": "Vanilla Frappe"},
        {"x0": 2262.0, "y0": 1892.0, "x1": 2686.0, "y1": 2313.0, "class_name": "Golden Fudge"},
        {"x0": 371.0, "y0": 2517.0, "x1": 858.0, "y1": 2820.0, "class_name": "Coconut"},
        {"x0": 1120.0, "y0": 2456.0, "x1": 1453.0, "y1": 2806.0, "class_name": "Lemon Creme"},
        {"x0": 1681.0, "y0": 2443.0, "x1": 2031.0, "y1": 2801.0, "class_name": "Lemon Creme"},
        {"x0": 2235.0, "y0": 2407.0, "x1": 2725.0, "y1": 2789.0, "class_name": "White Chocolate and Vanilla"},
        {"x0": 346.0, "y0": 2954.0, "x1": 877.0, "y1": 3262.0, "class_name": "Coconut"},
        {"x0": 1118.0, "y0": 2899.0, "x1": 1459.0, "y1": 3262.0, "class_name": "Hazelnut Praline"},
        {"x0": 1685.0, "y0": 2896.0, "x1": 2043.0, "y1": 3247.0, "class_name": "Hazelnut Praline"},
        {"x0": 2248.0, "y0": 2871.0, "x1": 2736.0, "y1": 3259.0, "class_name": "White Chocolate and Vanilla"}]


def find_bidimensional_minimum_record(data):
  # Initialize variables to store the minimum values and corresponding dictionary
  min_x0 = float('inf')
  min_y0 = float('inf')
  min_dict = None

  # Iterate through the data
  for entry in data:
      # Check if the current entry has smaller x0 and y0 values
      if entry['x0'] < min_x0 and entry['y0'] < min_y0:
          min_x0 = entry['x0']
          min_y0 = entry['y0']
          min_dict = entry

  # Print the dictionary with both the minimum x0 and y0
  return min_dict

final_sorted_candies = []

x0_check = 0
row_wise_candies = []
while data:
  min_dict = find_bidimensional_minimum_record(data)
  if x0_check > min_dict['x0']:
    final_sorted_candies.append(row_wise_candies)
    row_wise_candies = []
  row_wise_candies.append(min_dict['class_name'])
  x0_check = min_dict['x0']

  # Remove the minimum dict from the data
  data.remove(min_dict)

final_sorted_candies.append(row_wise_candies)
print(final_sorted_candies)
# Out:
# [['Crunchy Toffee', 'Signature Caramel', 'Signature Caramel', 'Chocolate Orange Creme Crunch', 'Chocolate Orange Creme Crunch'], ['Crunchy Toffee', 'Signature Caramel', 'Signature Caramel', 'Turkish Delight', 'Turkish Delight'], ['Vanilla Frappe', 'Golden Fudge', 'Vanilla Frappe', 'Golden Fudge'], ['Coconut', 'Lemon Creme', 'Lemon Creme', 'White Chocolate and Vanilla'], ['Coconut', 'Hazelnut Praline', 'Hazelnut Praline', 'White Chocolate and Vanilla']]

# %%
order = [
    [
        "Crunchy Toffee",
        "Signature Caramel",
        "Signature Caramel",
        "Chocolate Orange Creme Crunch",
        "Chocolate Orange Creme Crunch",
    ],
    [
        "Crunchy Toffee",
        "Signature Caramel",
        "Signature Caramel",
        "Turkish Delight",
        "Turkish Delight",
    ],
    ["Vanilla Frappe", "Vanilla Frappe", "Golden Fudge", "Golden Fudge"],
    ["Coconut", "Lemon Creme", "Lemon Creme", "White Chocolate and Vanilla"],
    ["Coconut", "Hazelnut Praline", "Hazelnut Praline", "White Chocolate and Vanilla"],
]

def compare_orders(order, final_sorted_candies):
    errors = []
    for row_counter, (order_row, detected_row) in enumerate(zip(order, final_sorted_candies)):
        for column_counter, (expected_candies, detected_candies) in enumerate(zip(order_row, detected_row)):
            if expected_candies != detected_candies:
                location_calculation = (5*(row_counter)) + (column_counter + 1)
                errors.append(f"Error at index {location_calculation}: expected {expected_candies}, detected {detected_candies}")
    return errors

errors = compare_orders(order, final_sorted_candies)

if errors:
    for error in errors:
        print(error)
else:
    print("No anomalies detected.")
# Out:
# Error at index 12: expected Vanilla Frappe, detected Golden Fudge
# Error at index 13: expected Golden Fudge, detected Vanilla Frappe

# %%
from PIL import Image, ImageDraw, ImageFont

data = [{"x0": 304.0, "y0": 886.0, "x1": 758.0, "y1": 1256.0, "class_name": "Crunchy Toffee"},
        {"x0": 918.0, "y0": 881.0, "x1": 1267.0, "y1": 1251.0, "class_name": "Signature Caramel"},
        {"x0": 1425.0, "y0": 878.0, "x1": 1766.0, "y1": 1248.0, "class_name": "Signature Caramel"},
        {"x0": 1895.0, "y0": 887.0, "x1": 2222.0, "y1": 1206.0, "class_name": "Chocolate Orange Creme Crunch"},
        {"x0": 2346.0, "y0": 887.0, "x1": 2662.0, "y1": 1184.0, "class_name": "Chocolate Orange Creme Crunch"},
        {"x0": 321.0, "y0": 1420.0, "x1": 771.0, "y1": 1784.0, "class_name": "Crunchy Toffee"},
        {"x0": 938.0, "y0": 1412.0, "x1": 1301.0, "y1": 1784.0, "class_name": "Signature Caramel"},
        {"x0": 1454.0, "y0": 1422.0, "x1": 1797.0, "y1": 1785.0, "class_name": "Signature Caramel"},
        {"x0": 1924.0, "y0": 1384.0, "x1": 2203.0, "y1": 1836.0, "class_name": "Turkish Delight"},
        {"x0": 2369.0, "y0": 1331.0, "x1": 2660.0, "y1": 1768.0, "class_name": "Turkish Delight"},
        {"x0": 397.0, "y0": 1963.0, "x1": 832.0, "y1": 2361.0, "class_name": "Vanilla Frappe"},
        {"x0": 1063.0, "y0": 1941.0, "x1": 1466.0, "y1": 2335.0, "class_name": "Golden Fudge"},
        {"x0": 1666.0, "y0": 1933.0, "x1": 2051.0, "y1": 2298.0, "class_name": "Vanilla Frappe"},
        {"x0": 2262.0, "y0": 1892.0, "x1": 2686.0, "y1": 2313.0, "class_name": "Golden Fudge"},
        {"x0": 371.0, "y0": 2517.0, "x1": 858.0, "y1": 2820.0, "class_name": "Coconut"},
        {"x0": 1120.0, "y0": 2456.0, "x1": 1453.0, "y1": 2806.0, "class_name": "Lemon Creme"},
        {"x0": 1681.0, "y0": 2443.0, "x1": 2031.0, "y1": 2801.0, "class_name": "Lemon Creme"},
        {"x0": 2235.0, "y0": 2407.0, "x1": 2725.0, "y1": 2789.0, "class_name": "White Chocolate and Vanilla"},
        {"x0": 346.0, "y0": 2954.0, "x1": 877.0, "y1": 3262.0, "class_name": "Coconut"},
        {"x0": 1118.0, "y0": 2899.0, "x1": 1459.0, "y1": 3262.0, "class_name": "Hazelnut Praline"},
        {"x0": 1685.0, "y0": 2896.0, "x1": 2043.0, "y1": 3247.0, "class_name": "Hazelnut Praline"},
        {"x0": 2248.0, "y0": 2871.0, "x1": 2736.0, "y1": 3259.0, "class_name": "White Chocolate and Vanilla"}]

# Find maximum coordinates
max_x = max(data, key=lambda x: x['x1'])['x1']
max_y = max(data, key=lambda x: x['y1'])['y1']

# Create blank image
image = Image.new("RGB", (int(max_x), int(max_y)), color="white")
draw = ImageDraw.Draw(image)

font = ImageFont.truetype("Gidole-Regular.ttf", size=20)
# Draw bounding boxes
for box in data:
    x0, y0, x1, y1 = box['x0'], box['y0'], box['x1'], box['y1']
    class_name = box['class_name']
    draw.rectangle([x0, y0, x1, y1], outline="black", width=2)

    center_x = (x0 + x1) // 2
    center_y = (y0 + y1) // 2
    text_width, text_height = draw.textsize(class_name)
    text_x = center_x - text_width // 2
    text_y = center_y - text_height // 2
    draw.text((text_x, text_y), class_name, fill="black", font=font)

# Save or display the image
image
# Out:
# <ipython-input-23-d9ab3988802e>:43: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(class_name)
# <ipython-input-23-d9ab3988802e>:43: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(class_name)
# <ipython-input-23-d9ab3988802e>:43: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(class_name)
# <ipython-input-23-d9ab3988802e>:43: DeprecationWarning: textsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use textbbox or textlength instead.
#   text_width, text_height = draw.textsize(class_name)
# ...
